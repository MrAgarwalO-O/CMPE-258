# %%
# !pip install transformers

# %%
# !pip install sentencepiece

# %%
from transformers import MarianMTModel, MarianTokenizer

# %%
def translate(text, target_language):
    model_name = f'Helsinki-NLP/opus-mt-en-{target_language}'
    tokenizer = MarianTokenizer.from_pretrained(model_name)
    model = MarianMTModel.from_pretrained(model_name)

    inputs = tokenizer.encode(text, return_tensors="pt")
    outputs = model.generate(inputs, num_beams=4, max_length=50, early_stopping=True)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return translated_text

# %%
input_text = "Welcome to Deep Learning, I am having fun playing with this part of assignment"
target_language = 'hi'
translated_text = translate(input_text, target_language)
print(translated_text)
# Out:
# गहरे सीखने में आपका स्वागत है, मैं इस नियुक्‍ति के इस भाग के साथ खेल रहा हूँ

# %%
input_text = "Welcome to Deep Learning, I am having fun playing with this part of assignment"
target_language = 'es'
translated_text = translate(input_text, target_language)
print(translated_text)
# Out:
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Bienvenido a Deep Learning, me estoy divirtiendo jugando con esta parte de la asignación

# %%
input_text = "Welcome to Deep Learning, I am having fun playing with this part of assignment"
target_language = 'zh'
translated_text = translate(input_text, target_language)
print(translated_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/806k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# 欢迎来到深学习, 我玩这个角色,玩得很开心

# %%
input_text = "Welcome to Deep Learning, I am having fun playing with this part of assignment"
target_language = 'fr'
translated_text = translate(input_text, target_language)
print(translated_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Bienvenue à Deep Learning, je m'amuse à jouer avec cette partie de l'affectation
